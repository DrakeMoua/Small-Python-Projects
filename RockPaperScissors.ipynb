# %%
#A simple Rock Paper Scissors game

from random import randint as rint

moves = ["rock", "paper", "scissors", "q"]
game = True
moveindex = {"r":0, "p":1, "s":2, "q":3}
win = 0
tie = 0
loss = 0

while game == True:
    print("Wins:", win,"\nTies:", tie,"\nLosses:", loss)
    cpumoven = rint(0,2)
    cpumove = moves[cpumoven]
    try:
        ipmove = moveindex[input("Choose your move by typing the first letter ex Rock = r. q to quit")]
        pmove = moves[ipmove]
        if pmove == "q":
            break
        if pmove == cpumove:
            tie += 1
            print("It is a tie!")
            
        elif pmove == "rock" and cpumove == "scissors":
            win += 1
        elif pmove == "paper" and cpumove == "rock":
            win += 1
        elif pmove == "scissors" and cpumove == "paper":
            win += 1
        else:
            loss += 1
            
        print("Your move:", pmove, "cpumove:", cpumove)
    except:
        print("Invalid Input")
# Out:
# Wins: 0
# Ties: 0
# Losses: 0
# Choose your move by typing the first letter ex Rock = r. q to quitr
# It is a tie!
# Your move: rock cpumove: rock
# Wins: 0
# Ties: 1
# Losses: 0
# Choose your move by typing the first letter ex Rock = r. q to quitr
# Your move: rock cpumove: paper
# Wins: 0
# Ties: 1
# Losses: 1
# Choose your move by typing the first letter ex Rock = r. q to quitr
# Your move: rock cpumove: paper
# Wins: 0
# Ties: 1
# Losses: 2
# Choose your move by typing the first letter ex Rock = r. q to quitr
# Your move: rock cpumove: paper
# Wins: 0
# Ties: 1
# Losses: 3
# Choose your move by typing the first letter ex Rock = r. q to quitr
# It is a tie!
# Your move: rock cpumove: rock
# Wins: 0
# Ties: 2
# Losses: 3
# Choose your move by typing the first letter ex Rock = r. q to quitr
# Your move: rock cpumove: paper
# Wins: 0
# Ties: 2
# Losses: 4
# Choose your move by typing the first letter ex Rock = r. q to quitr
# It is a tie!
# Your move: rock cpumove: rock
# Wins: 0
# Ties: 3
# Losses: 4
# Choose your move by typing the first letter ex Rock = r. q to quitr
# Your move: rock cpumove: paper
# Wins: 0
# Ties: 3
# Losses: 5
# Choose your move by typing the first letter ex Rock = r. q to quitr
# Your move: rock cpumove: scissors
# Wins: 1
# Ties: 3
# Losses: 5
# Choose your move by typing the first letter ex Rock = r. q to quitp
# Your move: paper cpumove: rock
# Wins: 2
# Ties: 3
# Losses: 5
# Choose your move by typing the first letter ex Rock = r. q to quitp
# Your move: paper cpumove: rock
# Wins: 3
# Ties: 3
# Losses: 5
# Choose your move by typing the first letter ex Rock = r. q to quitp
# It is a tie!
# Your move: paper cpumove: paper
# Wins: 3
# Ties: 4
# Losses: 5
# Choose your move by typing the first letter ex Rock = r. q to quitp
# Your move: paper cpumove: scissors
# Wins: 3
# Ties: 4
# Losses: 6
# Choose your move by typing the first letter ex Rock = r. q to quits
# It is a tie!
# Your move: scissors cpumove: scissors
# Wins: 3
# Ties: 5
# Losses: 6
# Choose your move by typing the first letter ex Rock = r. q to quits
# Your move: scissors cpumove: rock
# Wins: 3
# Ties: 5
# Losses: 7
# Choose your move by typing the first letter ex Rock = r. q to quits
# Your move: scissors cpumove: paper
# Wins: 4
# Ties: 5
# Losses: 7
# Choose your move by typing the first letter ex Rock = r. q to quitq
